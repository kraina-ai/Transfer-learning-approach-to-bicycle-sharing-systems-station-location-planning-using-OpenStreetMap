# %%
from osm_data_downloader.src.relation import load_area

# %%
cities = [
    # # Europe
    # 41485, # Rome, Italy
    # 2604796, # Athens, Greece
    # 42602, # Florence, Italy
    # 5400890, # Lisboa, Portugal
    # 449696, # Kraków, Poland

    # # North America
    # 175905, # New York, USA
    # 207359, # Los Angeles, USA
    # 122604, # Chicago, USA
    # 111968, # San Francisco, USA
    # 5396194, # Washington DC, USA
    # 1852574, # Vancouver, Canada
    # 324211, # Toronto, Canada
    # 1571328, # Montreal, Canada

    # # Asia
    # 5505984, # Beijing, China (Haidian District)
    # 5664191, # Shenzen, China (Futian District)
    # 1758858, # Tokio, Japan (Shinjuku District)
    # 2410520, # Seoul, South Korea (Gangnam-gu District)

    # 421007, # Saint Petersburg,
    # 377733, # Bucharest
    59195, # Minsk
    62782, #Hamburg
    3154746, #Kharkiv 
    2728438, #Belgrade
    4283101, #Sofia
    162378, #Birmingham
    1996871, #Tbilisi
    62578, #Cologne
    271110, #Amsterdam
    1906767, #Glasgow
    1513057, #Katowice
    2723259, #Gdańsk
    172987, #Liverpool
    146656, #Manchester
    76469, #Marseille
    40767, #Naples
    170100, #Nice
    62780, #Nuremberg
    3372453, #Porto
    3168167, #Zagreb

    2688911, #Houston
    111257, #Phoenix
    188022, #Philadelphia
    253556, #San Antonio
    253832, #San Diego
    113314, #Austin

    1376330, #Mexico City
    298285, #Sao Paulo
    7426387, #Bogota
    1224652, #Buenos Aires

    913067, #Shanghai
    3287617, #Guangzhou (Liwan District)
    4430941, #Suzhou
    2689482, #Yokohama
    2396450, #Busan
    358674, #Osaka
    4479752, #Dubai
    3970414, #Daegu (Dalseo-gu District)

    4246124, #Melbourne
    11677792, #Brisbane
    2093020, #Auckland (Waitematā District)
    119231, #Honolulu
    4266321, #Wellington

    5466227, #Cairo
    3851428, #Khartoum
    1707699, #Addis Ababa
    9185096, #Nairobi
]

for city in cities:
    relation = load_area(city)
    if relation is not None:
        relation.load_relations_to_file()
# Out:
#                                             geometry  osm_id    relation_name  \
# 0  MULTIPOLYGON (((27.37402 53.87204, 27.37649 53...   59195  Минск, Беларусь
#
#   administration_name
# 0     Минск, Беларусь
# [OSMPythonTools.Element] Cannot build geometry: no outer rings found.
# NoneType: None
# [OSMPythonTools.Element] Cannot build geometry: no outer rings found. (relation/5579041)
# Traceback (most recent call last):
#   File "/home/raczeq/anaconda3/lib/python3.8/site-packages/OSMPythonTools/element.py", line 161, in geometry
#     self._raiseException('Cannot build geometry: no outer rings found.')
#   File "/home/raczeq/anaconda3/lib/python3.8/site-packages/OSMPythonTools/element.py", line 46, in _raiseException
#     OSMPythonTools._raiseException('Element', msg)
#   File "/home/raczeq/anaconda3/lib/python3.8/site-packages/OSMPythonTools/__init__.py", line 13, in _raiseException
#     raise(Exception(msgComplete))
# ...
